# %%
import os
import re
from datetime import datetime

import re
import pandas as pd

log_directory = 'logs' # Replace with the correct Openstack Logs folder path

target_date_time = datetime(2023, 10, 20, 12, 00, 00)  # Replace with your desired date and time

# print("")
# print("Openstack Log Analyser")
# print("Enter with year, month, day, hour, minutes and seconds. The logs will gather from this date onwards")
# set_date_time_ge = int(input("sample format: 2023, 10, 30, 12, 00, 00: "))
# print(set_date_time_ge)
# target_date_time = datetime(set_date_time_ge) 

error_patterns = [
    r'ERROR',  # Add more error patterns as needed
    r'Exception',
    r'failed',
]

for root, dirs, files in os.walk(log_directory):
    for file in files:
        if file.endswith('.log'):
            log_file_path = os.path.join(root, file)
            with open(log_file_path, 'r') as log_file:
                for line_number, line in enumerate(log_file, start=1):
                    log_timestamp = re.search(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}', line)
                    if log_timestamp:
                        log_timestamp = datetime.strptime(log_timestamp.group(), '%Y-%m-%d %H:%M:%S')
                        if log_timestamp >= target_date_time:
                            if any(re.search(pattern, line) for pattern in error_patterns):
                                # print(f'Error message found in: {log_file_path} (Line {line_number}): {line}')
                                arr_errors = []
                                for line in log_file:
                                    if re.search('ERROR', line) and re.search('] ', line):
                                        arr_errors.append( line.split('] ')[-1].strip() )
                            pd.set_option('display.max_colwidth', None)
                            df = pd.DataFrame(arr_errors)
                            df.columns = ['mgs']
                            df = df.groupby(['mgs']).size().reset_index()
                            df.columns = ['mgs', 'count']
df
# Out:
#                                                                                                                                                                                                                                                                                                       mgs  \
# 0   AMQP server on 192.168.15.245:5672 is unreachable: (0, 0): (320) CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'. Trying again in 1 seconds.: amqp.exceptions.ConnectionForced: (0, 0): (320) CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'
# 1                                                                                     AMQP server on 192.168.15.245:5672 is unreachable: <RecoverableConnectionError: unknown error>. Trying again in 1 seconds.: amqp.exceptions.RecoverableConnectionError: <RecoverableConnectionError: unknown error>
# 2                                                                                                                                              AMQP server on 192.168.15.245:5672 is unreachable: Basic.cancel: (0) 1. Trying again in 1 seconds.: amqp.exceptions.ConsumerCancelled: Basic.cancel: (0) 1
# 3                                                                                                                                              AMQP server on 192.168.15.245:5672 is unreachable: Basic.cancel: (0) 3. Trying again in 1 seconds.: amqp.exceptions.ConsumerCancelled: Basic.cancel: (0) 3
# 4                                                                                                                                    AMQP server on 192.168.15.245:5672 is unreachable: Server unexpectedly closed connection. Trying again in 2 seconds.: OSError: Server unexpectedly closed connection
# 5                                                                                                                                    AMQP server on 192.168.15.245:5672 is unreachable: Server unexpectedly closed connection. Trying again in 4 seconds.: OSError: Server unexpectedly closed connection
# 6                                                                                                                                 AMQP server on 192.168.15.245:5672 is unreachable: Too many heartbeats missed. Trying again in 1 seconds.: amqp.exceptions.ConnectionForced: Too many heartbeats missed
# 7                                                                                                                                                                                                                                                                  Backup running in single process mode.
# 8                                                                                                                                                                      Connection failed: Server unexpectedly closed connection (retrying in 1.0 seconds): OSError: Server unexpectedly closed connection
# 9                                                                                                                                                                     Connection failed: Server unexpectedly closed connection (retrying in 11.0 seconds): OSError: Server unexpectedly closed connection
# 10                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 13.0 seconds): OSError: Server unexpectedly closed connection
# 11                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 15.0 seconds): OSError: Server unexpectedly closed connection
# 12                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 17.0 seconds): OSError: Server unexpectedly closed connection
# 13                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 19.0 seconds): OSError: Server unexpectedly closed connection
# 14                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 21.0 seconds): OSError: Server unexpectedly closed connection
# 15                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 23.0 seconds): OSError: Server unexpectedly closed connection
# 16                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 25.0 seconds): OSError: Server unexpectedly closed connection
# 17                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 27.0 seconds): OSError: Server unexpectedly closed connection
# 18                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 29.0 seconds): OSError: Server unexpectedly closed connection
# 19                                                                                                                                                                     Connection failed: Server unexpectedly closed connection (retrying in 3.0 seconds): OSError: Server unexpectedly closed connection
# 20                                                                                                                                                                    Connection failed: Server unexpectedly closed connection (retrying in 31.0 seconds): OSError: Server unexpectedly closed connection
# 21                                                                                                                                                                     Connection failed: Server unexpectedly closed connection (retrying in 5.0 seconds): OSError: Server unexpectedly closed connection
# 22                                                                                                                                                                     Connection failed: Server unexpectedly closed connection (retrying in 7.0 seconds): OSError: Server unexpectedly closed connection
# 23                                                                                                                                                                     Connection failed: Server unexpectedly closed connection (retrying in 9.0 seconds): OSError: Server unexpectedly closed connection
# 24                                                                                                                                                                                                                                                                               Connection reset by peer
# 25                                                                                                                                                                                                                                                                                           ECONNREFUSED
# 26                                                                                       Error during BackupManager.publish_service_capabilities: oslo_messaging.exceptions.MessageDeliveryFailure: Unable to connect to AMQP server on 192.168.15.245:5672 after inf tries: (0, 0): (541) INTERNAL_ERROR
# 27                                                                                                                                                Failed to publish message to topic 'cinder-scheduler_fanout': (0, 0): (541) INTERNAL_ERROR: amqp.exceptions.InternalError: (0, 0): (541) INTERNAL_ERROR
# 28                                                                                                                                                                                     Manager for service cinder-backup node05 is reporting problems, not sending heartbeat. Service will appear "down".
# 29                                                                                                                                                                                                                                                  RADOS object not found (error calling conf_read_file)
# 30                                                                                                                                                                                                                             The broker has blocked the connection: connection blocked, see broker logs
# 31                                                                                                                                     Unable to connect to AMQP server on 192.168.15.245:5672 after inf tries: (0, 0): (541) INTERNAL_ERROR: amqp.exceptions.InternalError: (0, 0): (541) INTERNAL_ERROR
#
#     count
# 0       1
# 1    3695
# 2       1
# 3       1
# 4    3679
# 5    3675
# 6       1
# 7       2
# 8       2
# 9       2
# 10      2
# 11      2
# 12      2
# 13      2
# 14      2
# 15      2
# 16      2
# 17      2
# 18      2
# 19      2
# 20    812
# 21      2
# 22      2
# 23      2
# 24      1
# 25     42
# 26      2
# 27      2
# 28  70099
# 29      8
# 30      4
# 31      2
